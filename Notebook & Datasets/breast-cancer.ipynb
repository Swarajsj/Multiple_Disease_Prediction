# %% [markdown]
# # Breast Cancer Prediction

# %% [markdown]
# ##  Importing libraries

# %%
# Importing libraries

import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

import warnings
warnings.filterwarnings('ignore')

sns.set()
plt.style.use('ggplot')

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('Breast_Cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
df.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'] = df['diagnosis'].apply(lambda val: 1 if val == 'M' else 0)

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  4.990000e+02  499.000000   499.000000    499.000000      499.000000
# mean   3.269570e+07    0.388778    14.211449     19.082004       92.516052
# std    1.328184e+08    0.487962     3.468564      4.167902       23.921803
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.670505e+05    0.000000    11.805000     16.070000       75.900000
# 50%    9.015490e+05    0.000000    13.430000     18.660000       86.600000
# 75%    8.910868e+06    1.000000    16.090000     21.565000      106.000000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   499.000000       499.000000        499.000000      499.000000
# mean    661.527856         0.095953          0.103827        0.089683
# std     348.463270         0.013669          0.053080        0.080131
# min     143.500000         0.062510          0.019380        0.000000
# 25%     430.000000         0.085985          0.063515        0.028860
# 50%     555.100000         0.095790          0.090970        0.063870
# 75%     799.400000         0.105000          0.130450        0.132000
# max    2501.000000         0.144700          0.345400        0.426800
#
#        concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count           499.000000  ...    499.000000     499.000000       499.000000
# mean              0.049320  ...     16.407074      25.497976       108.148216
# std               0.038813  ...      4.799700       6.064644        33.254942
# min               0.000000  ...      7.930000      12.020000        50.410000
# 25%               0.020220  ...     13.095000      21.005000        84.555000
# 50%               0.033840  ...     14.980000      25.220000        97.960000
# 75%               0.074855  ...     19.230000      29.295000       127.100000
# max               0.201200  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   499.000000        499.000000         499.000000       499.000000
# mean    894.271743          0.131943           0.256117         0.275936
# std     570.332259          0.022753           0.159239         0.208941
# min     185.200000          0.071170           0.027290         0.000000
# 25%     522.300000          0.116200           0.145850         0.114450
# 50%     689.100000          0.131200           0.214100         0.231000
# 75%    1144.000000          0.145650           0.342450         0.388400
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            499.000000      499.000000               499.000000
# mean               0.115789        0.292301                 0.083765
# std                0.065824        0.063399                 0.018124
# min                0.000000        0.156500                 0.055040
# 25%                0.063255        0.252000                 0.071270
# 50%                0.100100        0.283300                 0.079870
# 75%                0.166500        0.320100                 0.092070
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       499 non-null    int64
#  1   diagnosis                499 non-null    int64
#  2   radius_mean              499 non-null    float64
#  3   texture_mean             499 non-null    float64
#  4   perimeter_mean           499 non-null    float64
#  5   area_mean                499 non-null    float64
#  6   smoothness_mean          499 non-null    float64
#  7   compactness_mean         499 non-null    float64
#  8   concavity_mean           499 non-null    float64
#  9   concave points_mean      499 non-null    float64
#  10  symmetry_mean            499 non-null    float64
#  11  fractal_dimension_mean   499 non-null    float64
#  12  radius_se                499 non-null    float64
#  13  texture_se               499 non-null    float64
#  14  perimeter_se             499 non-null    float64
#  15  area_se                  499 non-null    float64
#  16  smoothness_se            499 non-null    float64
#  17  compactness_se           499 non-null    float64
#  18  concavity_se             499 non-null    float64
#  19  concave points_se        499 non-null    float64
#  20  symmetry_se              499 non-null    float64
#  21  fractal_dimension_se     499 non-null    float64
#  22  radius_worst             499 non-null    float64
#  23  texture_worst            499 non-null    float64
#  24  perimeter_worst          499 non-null    float64
#  25  area_worst               499 non-null    float64
#  26  smoothness_worst         499 non-null    float64
#  27  compactness_worst        499 non-null    float64
#  28  concavity_worst          499 non-null    float64
#  29  concave points_worst     499 non-null    float64
#  30  symmetry_worst           499 non-null    float64
#  31  fractal_dimension_worst  499 non-null    float64
# dtypes: float64(30), int64(2)
# memory usage: 124.9 KB

# %%
# checking for null values

df.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# visualizing null values

msno.bar(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### There are no missing values in the data.

# %%
df.describe()
plt.hist(df['diagnosis'])
plt.title('Diagnosis (M=1 , B=0)')
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 30:
        ax = plt.subplot(5, 6, plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column)
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# heatmap 

plt.figure(figsize = (20, 12))

corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype = bool))

sns.heatmap(corr, mask = mask, linewidths = 1, annot = True, fmt = ".2f")
plt.show()

# %% [markdown]
# ### We can see that there are many columns which are very highly correlated which causes multicollinearity so we have to remove highly correlated features.

# %%
# removing highly correlated features

corr_matrix = df.corr().abs() 

mask = np.triu(np.ones_like(corr_matrix, dtype = bool))
tri_df = corr_matrix.mask(mask)

to_drop = [x for x in tri_df.columns if any(tri_df[x] > 0.92)]

df = df.drop(to_drop, axis = 1)

print(f"The reduced dataframe has {df.shape[1]} columns.")
# Out:
# The reduced dataframe has 25 columns.

# %%
to_drop
# Out:
# ['radius_mean',
#  'perimeter_mean',
#  'area_mean',
#  'radius_se',
#  'perimeter_se',
#  'radius_worst',
#  'perimeter_worst']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       499 non-null    int64
#  1   diagnosis                499 non-null    int64
#  2   texture_mean             499 non-null    float64
#  3   smoothness_mean          499 non-null    float64
#  4   compactness_mean         499 non-null    float64
#  5   concavity_mean           499 non-null    float64
#  6   concave points_mean      499 non-null    float64
#  7   symmetry_mean            499 non-null    float64
#  8   fractal_dimension_mean   499 non-null    float64
#  9   texture_se               499 non-null    float64
#  10  area_se                  499 non-null    float64
#  11  smoothness_se            499 non-null    float64
#  12  compactness_se           499 non-null    float64
#  13  concavity_se             499 non-null    float64
#  14  concave points_se        499 non-null    float64
#  15  symmetry_se              499 non-null    float64
#  16  fractal_dimension_se     499 non-null    float64
#  17  texture_worst            499 non-null    float64
#  18  area_worst               499 non-null    float64
#  19  smoothness_worst         499 non-null    float64
#  20  compactness_worst        499 non-null    float64
#  21  concavity_worst          499 non-null    float64
#  22  concave points_worst     499 non-null    float64
#  23  symmetry_worst           499 non-null    float64
#  24  fractal_dimension_worst  499 non-null    float64
# dtypes: float64(23), int64(2)
# memory usage: 97.6 KB

# %%
# creating features and label 

X = df.drop('diagnosis', axis = 1)
y = df['diagnosis']

# %%
# splitting data into training and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
# scaling data

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
# fitting data to model

from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# model predictions

y_pred = log_reg.predict(X_test)

# %%
# accuracy score

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(accuracy_score(y_train, log_reg.predict(X_train)))

log_reg_acc = accuracy_score(y_test, log_reg.predict(X_test))
print(log_reg_acc)
# Out:
# 0.9799426934097422
# 0.9733333333333334

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[94  1]
#  [ 3 52]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        95
#            1       0.98      0.95      0.96        55
#
#     accuracy                           0.97       150
#    macro avg       0.98      0.97      0.97       150
# weighted avg       0.97      0.97      0.97       150

# %% [markdown]
# # K Neighbors Classifier (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# model predictions 

y_pred = knn.predict(X_test)

# %%
# accuracy score

print(accuracy_score(y_train, knn.predict(X_train)))

knn_acc = accuracy_score(y_test, knn.predict(X_test))
print(knn_acc)
# Out:
# 0.9656160458452722
# 0.9466666666666667

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[93  2]
#  [ 6 49]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        95
#            1       0.96      0.89      0.92        55
#
#     accuracy                           0.95       150
#    macro avg       0.95      0.93      0.94       150
# weighted avg       0.95      0.95      0.95       150

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

svc = SVC(probability=True)
parameters = {
    'gamma' : [0.0001, 0.001, 0.01, 0.1],
    'C' : [0.01, 0.05, 0.5, 0.1, 1, 10, 15, 20]
}

grid_search = GridSearchCV(svc, parameters)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid={'C': [0.01, 0.05, 0.5, 0.1, 1, 10, 15, 20],
#                          'gamma': [0.0001, 0.001, 0.01, 0.1]})

# %%
# best parameters

grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 0.01}

# %%
# best score 

grid_search.best_score_
# Out:
# 0.9742857142857144

# %%
svc = SVC(C = 10, gamma = 0.01, probability=True)
svc.fit(X_train, y_train)
# Out:
# SVC(C=10, gamma=0.01, probability=True)

# %%
# model predictions 

y_pred = svc.predict(X_test)

# %%
# accuracy score

print(accuracy_score(y_train, svc.predict(X_train)))

svc_acc = accuracy_score(y_test, svc.predict(X_test))
print(svc_acc)
# Out:
# 0.9828080229226361
# 0.9866666666666667

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[95  0]
#  [ 2 53]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        95
#            1       1.00      0.96      0.98        55
#
#     accuracy                           0.99       150
#    macro avg       0.99      0.98      0.99       150
# weighted avg       0.99      0.99      0.99       150

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()

parameters = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : range(2, 32, 1),
    'min_samples_leaf' : range(1, 10, 1),
    'min_samples_split' : range(2, 10, 1),
    'splitter' : ['best', 'random']
}

grid_search_dt = GridSearchCV(dtc, parameters, cv = 5, n_jobs = -1, verbose = 1)
grid_search_dt.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8640 candidates, totalling 43200 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 32),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
# best parameters

grid_search_dt.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 28,
#  'min_samples_leaf': 3,
#  'min_samples_split': 9,
#  'splitter': 'random'}

# %%
# best score

grid_search_dt.best_score_
# Out:
# 0.9514285714285714

# %%
dtc = DecisionTreeClassifier(criterion= 'entropy', max_depth= 19, min_samples_leaf= 4, min_samples_split= 6, splitter= 'random')
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=19, min_samples_leaf=4,
#                        min_samples_split=6, splitter='random')

# %%
y_pred = dtc.predict(X_test)

# %%
# accuracy score

print(accuracy_score(y_train, dtc.predict(X_train)))

dtc_acc = accuracy_score(y_test, dtc.predict(X_test))
print(dtc_acc)
# Out:
# 0.9656160458452722
# 0.9666666666666667

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[91  4]
#  [ 1 54]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        95
#            1       0.93      0.98      0.96        55
#
#     accuracy                           0.97       150
#    macro avg       0.96      0.97      0.96       150
# weighted avg       0.97      0.97      0.97       150

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rand_clf = RandomForestClassifier(criterion = 'entropy', max_depth = 10, max_features = 'auto', min_samples_leaf = 2, min_samples_split = 3, n_estimators = 130)
rand_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, max_features='auto',
#                        min_samples_leaf=2, min_samples_split=3,
#                        n_estimators=130)

# %%
y_pred = rand_clf.predict(X_test)

# %%
# accuracy score

print(accuracy_score(y_train, rand_clf.predict(X_train)))

ran_clf_acc = accuracy_score(y_test, y_pred)
print(ran_clf_acc)
# Out:
# 1.0
# 0.9733333333333334

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[94  1]
#  [ 3 52]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        95
#            1       0.98      0.95      0.96        55
#
#     accuracy                           0.97       150
#    macro avg       0.98      0.97      0.97       150
# weighted avg       0.97      0.97      0.97       150

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier()

parameters = {
    'loss': ['deviance', 'exponential'],
    'learning_rate': [0.001, 0.1],
    'n_estimators': [100, 150, 180]
}

grid_search_gbc = GridSearchCV(gbc, parameters, cv = 2, n_jobs = -5, verbose = 1)
grid_search_gbc.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 12 candidates, totalling 24 fits
# GridSearchCV(cv=2, estimator=GradientBoostingClassifier(), n_jobs=-5,
#              param_grid={'learning_rate': [0.001, 0.1],
#                          'loss': ['deviance', 'exponential'],
#                          'n_estimators': [100, 150, 180]},
#              verbose=1)

# %%
# best parameters 

grid_search_gbc.best_params_
# Out:
# {'learning_rate': 0.1, 'loss': 'deviance', 'n_estimators': 180}

# %%
# best score

grid_search_gbc.best_score_
# Out:
# 0.9427914614121511

# %%
gbc = GradientBoostingClassifier(learning_rate = 0.1, loss = 'exponential', n_estimators = 180)
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(loss='exponential', n_estimators=180)

# %%
y_pred = gbc.predict(X_test)

# %%
# accuracy score

print(accuracy_score(y_train, gbc.predict(X_train)))

gbc_acc = accuracy_score(y_test, y_pred)
print(gbc_acc)
# Out:
# 1.0
# 0.98

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[93  2]
#  [ 1 54]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        95
#            1       0.96      0.98      0.97        55
#
#     accuracy                           0.98       150
#    macro avg       0.98      0.98      0.98       150
# weighted avg       0.98      0.98      0.98       150

# %% [markdown]
# # Extreme Gradient Boosting

# %%
from xgboost import XGBClassifier 

xgb = XGBClassifier(objective = 'binary:logistic', learning_rate = 0.01, max_depth = 5, n_estimators = 180)

xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.01, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=180,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
# accuracy score

print(accuracy_score(y_train, xgb.predict(X_train)))

xgb_acc = accuracy_score(y_test, y_pred)
print(xgb_acc)
# Out:
# 1.0
# 0.9533333333333334

# %%
# confusion matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[92  3]
#  [ 4 51]]

# %%
# classification report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96        95
#            1       0.94      0.93      0.94        55
#
#     accuracy                           0.95       150
#    macro avg       0.95      0.95      0.95       150
# weighted avg       0.95      0.95      0.95       150

# %% [markdown]
# # Model Comparison

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN', 'SVM', 'Decision Tree Classifier', 'Random Forest Classifier', 'Gradient Boosting Classifier', 'XgBoost'],
    'Score': [100*round(log_reg_acc,4), 100*round(knn_acc,4), 100*round(svc_acc,4), 100*round(dtc_acc,4), 100*round(ran_clf_acc,4), 
              100*round(gbc_acc,4), 100*round(xgb_acc,4)]
})
models.sort_values(by = 'Score', ascending = False)
# Out:
#                           Model  Score
# 2                           SVM  98.67
# 5  Gradient Boosting Classifier  98.00
# 0           Logistic Regression  97.33
# 4      Random Forest Classifier  97.33
# 3      Decision Tree Classifier  96.67
# 6                       XgBoost  95.33
# 1                           KNN  94.67

# %%
import pickle
model = svc
pickle.dump(model, open("breast_ancer.pkl",'wb'))

# %%
from sklearn import metrics
plt.figure(figsize=(8,5))
models = [
{
    'label': 'LR',
    'model': log_reg,
},
{
    'label': 'DT',
    'model': dtc,
},
{
    'label': 'SVM',
    'model': svc,
},
{
    'label': 'KNN',
    'model': knn,
},
{
    'label': 'XGBoost',
    'model': xgb,
},
{
    'label': 'RF',
    'model': rand_clf,
},
{
    'label': 'GBDT',
    'model': gbc,
}
]
for m in models:
    model = m['model'] 
    model.fit(X_train, y_train) 
    y_pred=model.predict(X_test) 
    fpr1, tpr1, thresholds = metrics.roc_curve(y_test, model.predict_proba(X_test)[:,1])
    auc = metrics.roc_auc_score(y_test,model.predict(X_test))
    plt.plot(fpr1, tpr1, label='%s - ROC (area = %0.2f)' % (m['label'], auc))

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1 - Specificity (False Positive Rate)', fontsize=12)
plt.ylabel('Sensitivity (True Positive Rate)', fontsize=12)
plt.title('ROC - Breast Cancer Prediction', fontsize=12)
plt.legend(loc="lower right", fontsize=12)
plt.savefig("roc_breast_cancer.jpeg", format='jpeg', dpi=400, bbox_inches='tight')
plt.show()

# %%
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
models = [
{
    'label': 'LR',
    'model': log_reg,
},
{
    'label': 'DT',
    'model': dtc,
},
{
    'label': 'SVM',
    'model': svc,
},
{
    'label': 'KNN',
    'model': knn,
},
{
    'label': 'XGBoost',
    'model': xgb,
},
{
    'label': 'RF',
    'model': rand_clf,
},
{
    'label': 'GBDT',
    'model': gbc,
}
]

means_roc = []
means_accuracy = [100*round(log_reg_acc,4), 100*round(dtc_acc,4), 100*round(svc_acc,4), 100*round(knn_acc,4), 100*round(xgb_acc,4), 
                  100*round(ran_clf_acc,4), 100*round(gbc_acc,4)]

for m in models:
    model = m['model'] 
    model.fit(X_train, y_train) 
    y_pred=model.predict(X_test) 
    fpr1, tpr1, thresholds = metrics.roc_curve(y_test, model.predict_proba(X_test)[:,1])
    auc = metrics.roc_auc_score(y_test,model.predict(X_test))
    auc = 100*round(auc,4)
    means_roc.append(auc)

print(means_accuracy)
print(means_roc)

# data to plot
n_groups = 7
means_accuracy = tuple(means_accuracy)
means_roc = tuple(means_roc)

# create plot
fig, ax = plt.subplots(figsize=(8,5))
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_accuracy, bar_width,
alpha=opacity,
color='mediumpurple',
label='Accuracy (%)')

rects2 = plt.bar(index + bar_width, means_roc, bar_width,
alpha=opacity,
color='rebeccapurple',
label='ROC (%)')

plt.xlim([-1, 8])
plt.ylim([70, 104])

plt.title('Performance Evaluation - Breast Cancer Prediction', fontsize=12)
plt.xticks(index, ('   LR', '   DT', '   SVM', '   KNN', 'XGBoost' , '   RF', '   GBDT'), rotation=40, ha='center', fontsize=12)
plt.legend(loc="upper right", fontsize=10)
plt.savefig("PE_breast_cancer.jpeg", format='jpeg', dpi=400, bbox_inches='tight')
plt.show()
# Out:
# [97.33000000000001, 96.67, 98.67, 94.67, 95.33, 97.33000000000001, 98.0]
# [96.75, 94.02000000000001, 98.18, 93.49, 94.78, 95.30999999999999, 98.04]
